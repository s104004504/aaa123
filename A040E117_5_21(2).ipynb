# %% [markdown]
# <a href="https://colab.research.google.com/github/s104004504/aaa123/blob/master/A040E117_5_21(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.random.rand(100)

plt.scatter(x, y, c='g', alpha=0.5, label='scatters')
plt.legend()
plt.show()
